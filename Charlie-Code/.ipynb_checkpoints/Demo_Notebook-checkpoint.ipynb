# %%
import pandas as pd
data = pd.read_csv('c172_file_1.csv')
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_34676/2608906636.py in <module>
# ----> 1 data = pd.read_csv('c172_file_1.csv')
#       2 data
#
# NameError: name 'pd' is not defined

# %%
# %run real_demo.py
# Out:
# Epoch[1/5] Loss: 0.180
# Epoch[1/5] Loss: 0.165
# Epoch[1/5] Loss: 0.160
# Epoch[1/5] Loss: 0.158
# Epoch[1/5] Loss: 0.163
# Epoch[1/5] Loss: 0.147
# Epoch[1/5] Loss: 0.154
# Epoch[1/5] Loss: 0.180
# Epoch[1/5] Loss: 0.151
# Epoch[1/5] Loss: 0.165
# Epoch[1/5] Loss: 0.168
# Epoch[1/5] Loss: 0.178
# Epoch[2/5] Loss: 0.158
# Epoch[2/5] Loss: 0.171
# Epoch[2/5] Loss: 0.158
# Epoch[2/5] Loss: 0.161
# Epoch[2/5] Loss: 0.171
# Epoch[2/5] Loss: 0.154
# Epoch[2/5] Loss: 0.127
# Epoch[2/5] Loss: 0.169
# Epoch[2/5] Loss: 0.165
# Epoch[2/5] Loss: 0.138
# Epoch[2/5] Loss: 0.149
# Epoch[2/5] Loss: 0.156
# Epoch[2/5] Loss: 0.139
# Epoch[3/5] Loss: 0.125
# Epoch[3/5] Loss: 0.151
# Epoch[3/5] Loss: 0.122
# Epoch[3/5] Loss: 0.167
# Epoch[3/5] Loss: 0.156
# Epoch[3/5] Loss: 0.154
# Epoch[3/5] Loss: 0.132
# Epoch[3/5] Loss: 0.131
# Epoch[3/5] Loss: 0.133
# Epoch[3/5] Loss: 0.127
# Epoch[3/5] Loss: 0.135
# Epoch[3/5] Loss: 0.173
# Epoch[4/5] Loss: 0.118
# Epoch[4/5] Loss: 0.161
# Epoch[4/5] Loss: 0.116
# ...

# %%
# %run real_demo_2.py
# Out:
# Epoch[1/5] Loss: 0.029
# Epoch[1/5] Loss: 0.006
# Epoch[1/5] Loss: 0.010
# Epoch[1/5] Loss: 0.003
# Epoch[1/5] Loss: 0.001
# Epoch[1/5] Loss: 0.006
# Epoch[1/5] Loss: 0.020
# Epoch[1/5] Loss: 0.003
# Epoch[1/5] Loss: 0.003
# Epoch[1/5] Loss: 0.003
# Epoch[1/5] Loss: 0.002
# Epoch[1/5] Loss: 0.010
# Epoch[2/5] Loss: 0.007
# Epoch[2/5] Loss: 0.005
# Epoch[2/5] Loss: 0.004
# Epoch[2/5] Loss: 0.007
# Epoch[2/5] Loss: 0.002
# Epoch[2/5] Loss: 0.004
# Epoch[2/5] Loss: 0.002
# Epoch[2/5] Loss: 0.004
# Epoch[2/5] Loss: 0.003
# Epoch[2/5] Loss: 0.001
# Epoch[2/5] Loss: 0.005
# Epoch[2/5] Loss: 0.002
# Epoch[2/5] Loss: 0.004
# Epoch[3/5] Loss: 0.002
# Epoch[3/5] Loss: 0.004
# Epoch[3/5] Loss: 0.006
# Epoch[3/5] Loss: 0.004
# Epoch[3/5] Loss: 0.014
# Epoch[3/5] Loss: 0.004
# Epoch[3/5] Loss: 0.001
# Epoch[3/5] Loss: 0.004
# Epoch[3/5] Loss: 0.003
# Epoch[3/5] Loss: 0.002
# Epoch[3/5] Loss: 0.013
# Epoch[3/5] Loss: 0.009
# Epoch[4/5] Loss: 0.004
# Epoch[4/5] Loss: 0.001
# Epoch[4/5] Loss: 0.002
# ...
