# %%
import pandas as pd
data = pd.read_csv('c172_file_1.csv')
data
# Out:
#       AltAGL   AltB  AltGPS  AltMSL  BaroA  E1_CHT1  E1_CHT2  E1_CHT3  \
# 0        0.0  855.8   745.7   833.6  30.05   231.88   224.27   243.57
# 1        0.0  856.8   746.2   834.0  30.05   232.23   224.58   243.87
# 2        0.0  855.8   746.4   834.2  30.05   232.59   224.84   244.12
# 3        0.0  856.8   745.2   833.1  30.05   232.96   225.10   244.46
# 4        0.0  856.8   745.2   833.0  30.05   233.30   225.36   244.75
# ...      ...    ...     ...     ...    ...      ...      ...      ...
# 5055     0.0  844.2   751.5   839.3  30.02   282.56   270.85   296.29
# 5056     0.0  844.2   751.6   839.4  30.02   282.49   270.90   296.36
# 5057     0.0  844.2   751.7   839.5  30.02   282.43   270.93   296.42
# 5058     1.0  845.2   752.4   840.2  30.02   282.55   271.14   296.58
# 5059     0.0  845.2   751.0   838.8  30.02   282.44   271.07   296.52
#
#       E1_CHT4  E1_EGT1  ...  LatAc  NormAc   OAT  Pitch  Roll  TAS   VSpd  \
# ...

# %%
# %run real_demo.py
# Out:
# avg: tensor([[0.1341]], dtype=torch.float64, grad_fn=<SplitBackward>)
# logvar: tensor([[-0.1048]], dtype=torch.float64, grad_fn=<SplitBackward>)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\Desktop\NGAFID-REFERENCE\NGAFID_Anomaly_Detection\Charlie-Code\real_demo.py in <module>
#     189         for i in range(len(XX)):
#     190             localX = torch.tensor(XX[i])
# --> 191             recon, mu, logvar = demo(localX)
#     192             loss = loss_fn(recon, localX, mu, logvar)
#     193             optimizer.zero_grad()
#
# ~\anaconda3\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#    1049         if not (self._backward_hooks or self._forward_hooks or self._forward_pre_hooks or _global_backward_hooks
#    1050                 or _global_forward_hooks or _global_forward_pre_hooks):
# ...

# %%
# %run real_demo_2.py
# Out:
# tensor([[1.4457, 1.7993]])
# tensor([[-0.2512,  1.5122]])
# tensor([[ 0.1094, -0.1909]])
# tensor([[-0.0054, -0.5114]])
# tensor([[-1.4970,  0.2727]])
# tensor([[0.0429, 0.1487]])
# tensor([[-1.2389,  0.5972]])
# tensor([[-0.8779,  1.0557]])
# tensor([[ 1.9234, -0.7432]])
# tensor([[0.7153, 3.1107]])
# tensor([[-0.7609, -0.6671]])
# tensor([[0.8247, 0.4270]])
# tensor([[ 0.2170, -0.0091]])
# tensor([[ 0.5738, -1.0065]])
# tensor([[ 0.0112, -0.7484]])
# tensor([[0.3641, 0.4768]])
# tensor([[ 0.2881, -0.4137]])
# tensor([[-2.5289,  0.4870]])
# tensor([[0.3464, 0.0374]])
# tensor([[-0.4974,  0.1217]])
# tensor([[-0.3079, -1.5233]])
# tensor([[-1.1430, -0.9726]])
# tensor([[0.9221, 0.1895]])
# tensor([[-0.1380,  1.7054]])
# tensor([[ 1.5842, -1.5386]])
# tensor([[0.6247, 0.8178]])
# tensor([[-0.3730, -1.6803]])
# tensor([[-0.6230, -0.8621]])
# tensor([[-0.9479,  0.7840]])
# tensor([[-2.3399,  0.2344]])
# tensor([[0.6969, 0.5534]])
# tensor([[-0.1864, -1.2936]])
# ...
